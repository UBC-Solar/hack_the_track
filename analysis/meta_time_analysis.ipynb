# %% [markdown]
# # Investigating Timestamps

# %%
import pandas as pd

# %% [markdown]
# You'll need to put in your own path here.

# %%
df = pd.read_csv('/Users/joshuariefman/Solar/hack_the_track/barber/R1_barber_telemetry_data.csv')

# %% [markdown]
# Let's grab the vehicles to ensure no duplicates (since vehicle number isn't guaranteed to be unique, unlike chassis number)

# %%
vehicles = df['original_vehicle_id'].unique()
vehicles
# Out:
# array(['GR86-002-000', 'GR86-004-78', 'GR86-006-7', 'GR86-010-16',
#        'GR86-013-80', 'GR86-015-31', 'GR86-016-55', 'GR86-022-13',
#        'GR86-025-47', 'GR86-026-72', 'GR86-030-18', 'GR86-033-46',
#        'GR86-036-98', 'GR86-038-93', 'GR86-040-3', 'GR86-047-21',
#        'GR86-049-88', 'GR86-060-2', 'GR86-063-113', 'GR86-065-5'],
#       dtype=object)

# %% [markdown]
# Let's collect the initial `meta_time` values for each vehicle, and compare the `meta_time` for start and end with the ECU time, `timestamp`.

# %%
meta_start_times = []

for vehicle in vehicles:
    vehicle_df = df[df['original_vehicle_id'] == vehicle]

    vehicle_df = vehicle_df.copy()

    vehicle_df['timestamp'] = pd.to_datetime(vehicle_df['timestamp'])
    vehicle_df['meta_time'] = pd.to_datetime(vehicle_df['meta_time'])
    
    ecu_start_time = vehicle_df['timestamp'].min()
    ecu_end_time = vehicle_df['timestamp'].max()
    meta_start_time = vehicle_df['meta_time'].min()
    meta_end_time = vehicle_df['meta_time'].max()
    
    meta_start_times.append(meta_start_time)
    
    print(f" --- {vehicle} ---")
    print(f"ecu_start_time: {ecu_start_time}")
    print(f"ecu_end_time: {ecu_end_time}")
    print(f"meta_start_time: {meta_start_time}")
    print(f"meta_end_time: {meta_end_time}")
    print(f"meta_start_time - ecu_start_time: {meta_start_time - ecu_start_time}")
    print(f"meta_end_time - meta_start_time: {meta_end_time - meta_start_time}")
    print(f"ecu_end_time - ecu_start_time: {ecu_end_time - ecu_start_time}")
# Out:
#  --- GR86-002-000 ---
# ecu_start_time: 2025-09-05 00:27:38.589000+00:00
# ecu_end_time: 2025-09-05 01:12:36.506000+00:00
# meta_start_time: 2025-09-06 18:40:01.639000+00:00
# meta_end_time: 2025-09-06 19:24:57.859000+00:00
# meta_start_time - ecu_start_time: 1 days 18:12:23.050000
# meta_end_time - meta_start_time: 0 days 00:44:56.220000
# ecu_end_time - ecu_start_time: 0 days 00:44:57.917000
#  --- GR86-004-78 ---
# ecu_start_time: 2025-09-04 18:25:20.166000+00:00
# ecu_end_time: 2025-09-04 18:25:20.166000+00:00
# meta_start_time: 2025-09-06 18:40:01.644000+00:00
# meta_end_time: 2025-09-06 19:24:59.961000+00:00
# meta_start_time - ecu_start_time: 2 days 00:14:41.478000
# meta_end_time - meta_start_time: 0 days 00:44:58.317000
# ecu_end_time - ecu_start_time: 0 days 00:00:00
#  --- GR86-006-7 ---
# ecu_start_time: 2025-09-04 23:32:56.117000+00:00
# ecu_end_time: 2025-09-05 00:17:54.209000+00:00
# meta_start_time: 2025-09-06 18:40:01.540000+00:00
# meta_end_time: 2025-09-06 19:24:59.984000+00:00
# meta_start_time - ecu_start_time: 1 days 19:07:05.423000
# meta_end_time - meta_start_time: 0 days 00:44:58.444000
# ecu_end_time - ecu_start_time: 0 days 00:44:58.092000
#  --- GR86-010-16 ---
# ecu_start_time: 2025-09-05 01:40:35.898000+00:00
# ecu_end_time: 2025-09-05 02:25:33.889000+00:00
# meta_start_time: 2025-09-06 18:40:01.645000+00:00
# meta_end_time: 2025-09-06 19:24:57.865000+00:00
# meta_start_time - ecu_start_time: 1 days 16:59:25.747000
# meta_end_time - meta_start_time: 0 days 00:44:56.220000
# ecu_end_time - ecu_start_time: 0 days 00:44:57.991000
#  --- GR86-013-80 ---
# ecu_start_time: 2025-09-04 18:25:34.971000+00:00
# ecu_end_time: 2025-09-04 18:25:34.971000+00:00
# meta_start_time: 2025-09-06 18:40:01.541000+00:00
# meta_end_time: 2025-09-06 19:24:57.933000+00:00
# meta_start_time - ecu_start_time: 2 days 00:14:26.570000
# meta_end_time - meta_start_time: 0 days 00:44:56.392000
# ecu_end_time - ecu_start_time: 0 days 00:00:00
#  --- GR86-015-31 ---
# ecu_start_time: 2025-09-04 23:35:25.981000+00:00
# ecu_end_time: 2025-09-05 00:20:23.960000+00:00
# meta_start_time: 2025-09-06 18:40:01.545000+00:00
# meta_end_time: 2025-09-06 19:24:57.934000+00:00
# meta_start_time - ecu_start_time: 1 days 19:04:35.564000
# meta_end_time - meta_start_time: 0 days 00:44:56.389000
# ecu_end_time - ecu_start_time: 0 days 00:44:57.979000
#  --- GR86-016-55 ---
# ecu_start_time: 2025-09-05 00:03:36.313000+00:00
# ecu_end_time: 2025-09-05 00:48:35.433000+00:00
# meta_start_time: 2025-09-06 18:40:01.639000+00:00
# meta_end_time: 2025-09-06 19:24:59.984000+00:00
# meta_start_time - ecu_start_time: 1 days 18:36:25.326000
# meta_end_time - meta_start_time: 0 days 00:44:58.345000
# ecu_end_time - ecu_start_time: 0 days 00:44:59.120000
#  --- GR86-022-13 ---
# ecu_start_time: 2025-09-05 00:42:29.258000+00:00
# ecu_end_time: 2025-09-05 01:27:27.238000+00:00
# meta_start_time: 2025-09-06 18:40:01.541000+00:00
# meta_end_time: 2025-09-06 19:24:57.933000+00:00
# meta_start_time - ecu_start_time: 1 days 17:57:32.283000
# meta_end_time - meta_start_time: 0 days 00:44:56.392000
# ecu_end_time - ecu_start_time: 0 days 00:44:57.980000
#  --- GR86-025-47 ---
# ecu_start_time: 2025-09-05 19:05:00.445000+00:00
# ecu_end_time: 2025-09-05 19:49:58.394000+00:00
# meta_start_time: 2025-09-06 18:40:01.541000+00:00
# meta_end_time: 2025-09-06 19:24:57.933000+00:00
# meta_start_time - ecu_start_time: 0 days 23:35:01.096000
# meta_end_time - meta_start_time: 0 days 00:44:56.392000
# ecu_end_time - ecu_start_time: 0 days 00:44:57.949000
#  --- GR86-026-72 ---
# ecu_start_time: 2025-09-05 00:29:50.799000+00:00
# ecu_end_time: 2025-09-05 01:14:50.066000+00:00
# meta_start_time: 2025-09-06 18:40:01.541000+00:00
# meta_end_time: 2025-09-06 19:24:59.988000+00:00
# meta_start_time - ecu_start_time: 1 days 18:10:10.742000
# meta_end_time - meta_start_time: 0 days 00:44:58.447000
# ecu_end_time - ecu_start_time: 0 days 00:44:59.267000
#  --- GR86-030-18 ---
# ecu_start_time: 2025-09-05 01:16:13.776000+00:00
# ecu_end_time: 2025-09-05 02:01:11.746000+00:00
# meta_start_time: 2025-09-06 18:40:01.645000+00:00
# meta_end_time: 2025-09-06 19:24:57.866000+00:00
# meta_start_time - ecu_start_time: 1 days 17:23:47.869000
# meta_end_time - meta_start_time: 0 days 00:44:56.221000
# ecu_end_time - ecu_start_time: 0 days 00:44:57.970000
#  --- GR86-033-46 ---
# ecu_start_time: 2025-09-05 00:09:19.358000+00:00
# ecu_end_time: 2025-09-05 00:54:17.310000+00:00
# meta_start_time: 2025-09-06 18:40:01.541000+00:00
# meta_end_time: 2025-09-06 19:24:57.933000+00:00
# meta_start_time - ecu_start_time: 1 days 18:30:42.183000
# meta_end_time - meta_start_time: 0 days 00:44:56.392000
# ecu_end_time - ecu_start_time: 0 days 00:44:57.952000
#  --- GR86-036-98 ---
# ecu_start_time: 2025-09-05 00:16:06.779000+00:00
# ecu_end_time: 2025-09-05 01:01:04.750000+00:00
# meta_start_time: 2025-09-06 18:40:01.645000+00:00
# meta_end_time: 2025-09-06 19:24:57.865000+00:00
# meta_start_time - ecu_start_time: 1 days 18:23:54.866000
# meta_end_time - meta_start_time: 0 days 00:44:56.220000
# ecu_end_time - ecu_start_time: 0 days 00:44:57.971000
#  --- GR86-038-93 ---
# ecu_start_time: 2025-09-05 06:16:00.388000+00:00
# ecu_end_time: 2025-09-05 07:01:00.431000+00:00
# meta_start_time: 2025-09-06 18:40:01.645000+00:00
# meta_end_time: 2025-09-06 19:24:59.969000+00:00
# meta_start_time - ecu_start_time: 1 days 12:24:01.257000
# meta_end_time - meta_start_time: 0 days 00:44:58.324000
# ecu_end_time - ecu_start_time: 0 days 00:45:00.043000
#  --- GR86-040-3 ---
# ecu_start_time: 2025-09-05 01:42:36.278000+00:00
# ecu_end_time: 2025-09-05 02:27:34.332000+00:00
# meta_start_time: 2025-09-06 18:40:01.540000+00:00
# meta_end_time: 2025-09-06 19:24:59.984000+00:00
# meta_start_time - ecu_start_time: 1 days 16:57:25.262000
# meta_end_time - meta_start_time: 0 days 00:44:58.444000
# ecu_end_time - ecu_start_time: 0 days 00:44:58.054000
#  --- GR86-047-21 ---
# ecu_start_time: 2025-09-05 19:23:08.182000+00:00
# ecu_end_time: 2025-09-05 20:08:08.257000+00:00
# meta_start_time: 2025-09-06 18:40:01.638000+00:00
# meta_end_time: 2025-09-06 19:24:59.979000+00:00
# meta_start_time - ecu_start_time: 0 days 23:16:53.456000
# meta_end_time - meta_start_time: 0 days 00:44:58.341000
# ecu_end_time - ecu_start_time: 0 days 00:45:00.075000
#  --- GR86-049-88 ---
# ecu_start_time: 2025-09-04 23:48:09.651000+00:00
# ecu_end_time: 2025-09-05 00:16:40.511000+00:00
# meta_start_time: 2025-09-06 18:40:01.653000+00:00
# meta_end_time: 2025-09-06 19:08:32.009000+00:00
# meta_start_time - ecu_start_time: 1 days 18:51:52.002000
# meta_end_time - meta_start_time: 0 days 00:28:30.356000
# ecu_end_time - ecu_start_time: 0 days 00:28:30.860000
#  --- GR86-060-2 ---
# ecu_start_time: 2025-09-05 00:23:16.714000+00:00
# ecu_end_time: 2025-09-05 01:08:14.808000+00:00
# meta_start_time: 2025-09-06 18:40:01.644000+00:00
# meta_end_time: 2025-09-06 19:24:59.961000+00:00
# meta_start_time - ecu_start_time: 1 days 18:16:44.930000
# meta_end_time - meta_start_time: 0 days 00:44:58.317000
# ecu_end_time - ecu_start_time: 0 days 00:44:58.094000
#  --- GR86-063-113 ---
# ecu_start_time: 2025-09-05 01:06:07.955000+00:00
# ecu_end_time: 2025-09-05 01:51:05.966000+00:00
# meta_start_time: 2025-09-06 18:40:01.645000+00:00
# meta_end_time: 2025-09-06 19:24:57.864000+00:00
# meta_start_time - ecu_start_time: 1 days 17:33:53.690000
# meta_end_time - meta_start_time: 0 days 00:44:56.219000
# ecu_end_time - ecu_start_time: 0 days 00:44:58.011000
#  --- GR86-065-5 ---
# ecu_start_time: 2025-09-05 00:37:04.024000+00:00
# ecu_end_time: 2025-09-05 01:22:02.932000+00:00
# meta_start_time: 2025-09-06 18:40:01.645000+00:00
# meta_end_time: 2025-09-06 19:24:59.972000+00:00
# meta_start_time - ecu_start_time: 1 days 18:02:57.621000
# meta_end_time - meta_start_time: 0 days 00:44:58.327000
# ecu_end_time - ecu_start_time: 0 days 00:44:58.908000

# %%
meta_start_times
# Out:
# [Timestamp('2025-09-06 18:40:01.639000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.644000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.540000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.645000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.541000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.545000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.639000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.541000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.541000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.541000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.645000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.541000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.645000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.645000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.540000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.638000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.653000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.644000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.645000+0000', tz='UTC'),
#  Timestamp('2025-09-06 18:40:01.645000+0000', tz='UTC')]

# %% [markdown]
# We see that while ECU times vary a lot (indicating that they are not correct in absolute value), the meta times only vary by 0.1s.
